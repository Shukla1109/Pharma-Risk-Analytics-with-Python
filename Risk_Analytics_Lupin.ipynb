# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
Lupin= yf.Ticker('LUPIN.NS')

# %%
Lupin= yf.Ticker('Lupin.NS')

# %%
Lupin.info
# Out:
# {'address1': 'Kalpataru Inspire',
#  'address2': '3rd Floor Off. Western Expressway Highway Santacruz (East)',
#  'city': 'Mumbai',
#  'zip': '400055',
#  'country': 'India',
#  'phone': '91 22 6640 2323',
#  'fax': '91 22 6640 2051',
#  'website': 'https://www.lupin.com',
#  'industry': 'Drug Manufacturers - Specialty & Generic',
#  'industryKey': 'drug-manufacturers-specialty-generic',
#  'industryDisp': 'Drug Manufacturers - Specialty & Generic',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...

# %%
fin =Lupin.quarterly_financials

# %%
fin
# Out:
#                                                        2024-09-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                       0.185219
# Normalized EBITDA                                   13826500000.0
# Net Income From Continuing Operation Net Minori...   8526300000.0
# Reconciled Depreciation                              2569200000.0
# Reconciled Cost Of Revenue                          16899400000.0
# EBITDA                                              13826500000.0
# EBIT                                                11257300000.0
# Net Interest Income                                  -708700000.0
# Interest Expense                                      708700000.0
# Normalized Income                                    8526300000.0
# Net Income From Continuing And Discontinued Ope...   8526300000.0
# Total Expenses                                      44456500000.0
# ...

# %% [markdown]
# Key Observations:
#
# Revenue Growth:
#
# Revenue has shown significant growth over the reported periods.
# Q2 2024 appears to have the highest revenue.
# Profitability:
#
# Net Income has also grown substantially, with Q2 2024 showing the highest figure.
# Diluted EPS has also increased, suggesting improved profitability per share.
# Expenses:
#
# Operating expenses have been increasing, which is a factor to monitor.
# Cost of revenue has also been increasing, potentially impacting profitability margins.
# EBITDA:
#
# EBITDA has generally been positive, indicating the company's ability to generate cash flow from operations.

# %%
Lupin.get_revenue_estimate()
# Out:
#      numberOfAnalysts           avg           low          high  \
# 0q                  4   56460889750   56214559000   56688000000
# +1q                 3   55483178330   54810000000   56718000000
# 0y                 35  223774387980  214570000000  227943000000
# +1y                35  250804462080  226387000000  272481000000
#
#      yearAgoRevenue  growth
# 0q      51974100000  0.0863
# +1q     49607900000  0.1184
# 0y     200108200000  0.1183
# +1y    223774387980  0.1208

# %%
Lupin.get_earnings_estimate()
# Out:
#      numberOfAnalysts       avg    low       high  yearAgoEps  growth
# 0q                  4  17.36390  16.00   19.28561    13.41000  0.2948
# +1q                 3  14.90145  12.25   17.45435     7.86000  0.8959
# 0y                 34  67.43683  60.35   75.74941    41.87000  0.6106
# +1y                33  82.88978  56.61  112.19000    67.43683  0.2291

# %%
Lupin.get_calendar()
# Out:
# {'Ex-Dividend Date': datetime.date(2024, 7, 16),
#  'Earnings Date': [datetime.date(2025, 2, 5), datetime.date(2025, 2, 10)],
#  'Earnings High': 19.28561,
#  'Earnings Low': 16.0,
#  'Earnings Average': 17.3639,
#  'Revenue High': 56688000000,
#  'Revenue Low': 56214559000,
#  'Revenue Average': 56460889750}

# %%
Lupin.balancesheet
# Out:
#                                                       2024-03-31  \
# Ordinary Shares Number                               455678908.0
# Share Issued                                         455678908.0
# Net Debt                                           14823100000.0
# Total Debt                                         29217700000.0
# Tangible Book Value                               101336800000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   21785400000.0
# Other Short Term Investments                        9909400000.0
# Cash And Cash Equivalents                          11876000000.0
# Cash Equivalents                                    4839500000.0
# Cash Financial                                      7036500000.0
#
#                                                      2023-03-31  \
# Ordinary Shares Number                              454981335.0
# ...

# %% [markdown]
# # Key Observations:
#
# Stable Share Structure: The number of Ordinary Shares has remained relatively stable across the reported periods, indicating no significant share issuances or buybacks.
#
# Increasing Debt Levels: Total Debt has increased substantially from 2020 to 2022, followed by a slight decrease in 2023. This could indicate increased borrowing to fund growth initiatives, acquisitions, or other strategic investments.
#
# Net Debt: Net Debt (Total Debt - Cash & Equivalents) has increased significantly over the period. This suggests a higher debt burden compared to cash reserves.
#
# Growing Cash Holdings: Cash and Cash Equivalents have shown a significant increase from 2020 to 2021, followed by a decrease in 2022 and a slight increase in 2023. This could suggest strong cash generation or reduced capital expenditures during this period.
#
# Increasing Tangible Book Value: Tangible Book Value has been increasing steadily over the reported periods, suggesting growth in the company's assets.

# %%
Lupin.major_holders
# Out:
# Breakdown                         Value
# insidersPercentHeld             0.47116
# institutionsPercentHeld         0.33650
# institutionsFloatPercentHeld    0.63630
# institutionsCount             200.00000

# %%
hist=Lupin.history(period='max')
hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2001-09-10 00:00:00+05:30     6.084319     6.838775     5.881509     6.534559
# 2001-09-11 00:00:00+05:30     6.672470     6.806325     6.307411     6.335804
# 2001-09-12 00:00:00+05:30     5.869341     6.084320     5.869341     5.974802
# 2001-09-13 00:00:00+05:30     6.003196     6.084320     5.885565     5.999139
# 2001-09-14 00:00:00+05:30     5.601630     5.743597     5.585405     5.585405
# ...                                ...          ...          ...          ...
# 2024-12-30 00:00:00+05:30  2227.800049  2328.750000  2226.850098  2311.350098
# 2024-12-31 00:00:00+05:30  2310.250000  2373.899902  2296.800049  2355.699951
# 2025-01-01 00:00:00+05:30  2354.000000  2369.399902  2336.800049  2364.899902
# 2025-01-02 00:00:00+05:30  2365.000000  2402.899902  2344.250000  2396.100098
# 2025-01-03 00:00:00+05:30  2388.850098  2394.750000  2347.350098  2368.850098
#
# ...

# %%
hist.index
# Out:
# DatetimeIndex(['2001-09-10 00:00:00+05:30', '2001-09-11 00:00:00+05:30',
#                '2001-09-12 00:00:00+05:30', '2001-09-13 00:00:00+05:30',
#                '2001-09-14 00:00:00+05:30', '2001-09-17 00:00:00+05:30',
#                '2001-09-18 00:00:00+05:30', '2001-09-19 00:00:00+05:30',
#                '2001-09-20 00:00:00+05:30', '2001-09-21 00:00:00+05:30',
#                ...
#                '2024-12-20 00:00:00+05:30', '2024-12-23 00:00:00+05:30',
#                '2024-12-24 00:00:00+05:30', '2024-12-26 00:00:00+05:30',
#                '2024-12-27 00:00:00+05:30', '2024-12-30 00:00:00+05:30',
#                '2024-12-31 00:00:00+05:30', '2025-01-01 00:00:00+05:30',
#                '2025-01-02 00:00:00+05:30', '2025-01-03 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=5800, freq=None)

# %%
data=hist.loc['2020-01-01':'2024-11-01']
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-01 00:00:00+05:30  744.956230  752.694909  744.956230  750.650757
# 2020-01-02 00:00:00+05:30  752.451561  759.606154  743.885500  754.982422
# 2020-01-03 00:00:00+05:30  755.274508  765.592707  749.531322  756.247925
# 2020-01-06 00:00:00+05:30  750.504672  753.862973  735.903414  741.889954
# 2020-01-07 00:00:00+05:30  743.690723  752.062087  732.545085  737.412170
#
#                             Volume  Dividends  Stock Splits
# Date
# 2020-01-01 00:00:00+05:30   465429        0.0           0.0
# 2020-01-02 00:00:00+05:30   867603        0.0           0.0
# 2020-01-03 00:00:00+05:30  1110452        0.0           0.0
# 2020-01-06 00:00:00+05:30   522118        0.0           0.0
# 2020-01-07 00:00:00+05:30   824059        0.0           0.0

# %%
data.plot(kind='line',figsize=(12,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# **Observation:**
#
# Overall Trend:
#
# Upward Trend: The overall trend of the stock price seems to be upward, with a general increase in price over the period shown.
# Price Fluctuations:
#
# Volatility: The price exhibits significant volatility, with periods of sharp increases and decreases. This suggests that the stock is relatively risky.
# Price Range: The price range between the high and low points of each day is substantial, indicating significant price fluctuations within trading sessions.
# Volume:
#
# Variable Volume: The trading volume fluctuates considerably. There are periods of high volume, which may indicate increased investor interest or significant news events, and periods of low volume, which could suggest less activity.
# Dividends:
#
# Dividend Payments: There are visible dividend payments indicated by the spikes in the "Dividends" line. These payouts likely provide some income to investors.
# Stock Splits:
#
# No Stock Splits: There are no stock splits indicated on the chart.
# Additional Observations:
#
# Possible Support and Resistance Levels: There might be some potential support and resistance levels visible on the chart, where the price tends to stall or reverse. Identifying these levels can be useful for technical analysis.

# %%
data['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Observations:**
#
# Overall Trend:
#
# Upward Trend: The overall trend of the stock price seems to be upward, with a general increase in price over the period shown.
# Price Fluctuations:
#
# Volatility: The price exhibits significant volatility, with periods of sharp increases and decreases. This suggests that the stock is relatively risky.
# Additional Observations:
#
# Possible Support and Resistance Levels: There might be some potential support and resistance levels visible on the chart, where the price tends to stall or reverse. Identifying these levels can be useful for technical analysis.

# %%
data['Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Observation:
#
# Upward Trend: The overall trend of the stock price seems to be upward, with a general increase in price over the period shown.
# Price Fluctuations:
#
# Volatility: The price exhibits significant volatility, with periods of sharp increases and decreases. This suggests that the stock is relatively risky.
# Additional Observations:
#
# Possible Support and Resistance Levels: There might be some potential support and resistance levels visible on the chart, where the price tends to stall or reverse. Identifying these levels can be useful for technical analysis.

# %%
data=data.reset_index()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1199 non-null   datetime64[ns, Asia/Kolkata]
#  1   Open          1199 non-null   float64
#  2   High          1199 non-null   float64
#  3   Low           1199 non-null   float64
#  4   Close         1199 non-null   float64
#  5   Volume        1199 non-null   int64
#  6   Dividends     1199 non-null   float64
#  7   Stock Splits  1199 non-null   float64
# dtypes: datetime64[ns, Asia/Kolkata](1), float64(6), int64(1)
# memory usage: 75.1 KB

# %%
data
# Out:
#                           Date         Open         High          Low  \
# 0    2020-01-01 00:00:00+05:30   744.956230   752.694909   744.956230
# 1    2020-01-02 00:00:00+05:30   752.451561   759.606154   743.885500
# 2    2020-01-03 00:00:00+05:30   755.274508   765.592707   749.531322
# 3    2020-01-06 00:00:00+05:30   750.504672   753.862973   735.903414
# 4    2020-01-07 00:00:00+05:30   743.690723   752.062087   732.545085
# ...                        ...          ...          ...          ...
# 1194 2024-10-28 00:00:00+05:30  2157.050049  2217.000000  2157.050049
# 1195 2024-10-29 00:00:00+05:30  2214.649902  2214.649902  2168.399902
# 1196 2024-10-30 00:00:00+05:30  2195.500000  2211.199951  2151.000000
# 1197 2024-10-31 00:00:00+05:30  2169.449951  2200.000000  2148.350098
# 1198 2024-11-01 00:00:00+05:30  2204.399902  2205.000000  2180.250000
#
#             Close   Volume  Dividends  Stock Splits
# 0      750.650757   465429        0.0           0.0
# ...

# %%
data.set_index(data['Date'])
# Out:
#                                                Date         Open         High  \
# Date
# 2020-01-01 00:00:00+05:30 2020-01-01 00:00:00+05:30   744.956230   752.694909
# 2020-01-02 00:00:00+05:30 2020-01-02 00:00:00+05:30   752.451561   759.606154
# 2020-01-03 00:00:00+05:30 2020-01-03 00:00:00+05:30   755.274508   765.592707
# 2020-01-06 00:00:00+05:30 2020-01-06 00:00:00+05:30   750.504672   753.862973
# 2020-01-07 00:00:00+05:30 2020-01-07 00:00:00+05:30   743.690723   752.062087
# ...                                             ...          ...          ...
# 2024-10-28 00:00:00+05:30 2024-10-28 00:00:00+05:30  2157.050049  2217.000000
# 2024-10-29 00:00:00+05:30 2024-10-29 00:00:00+05:30  2214.649902  2214.649902
# 2024-10-30 00:00:00+05:30 2024-10-30 00:00:00+05:30  2195.500000  2211.199951
# 2024-10-31 00:00:00+05:30 2024-10-31 00:00:00+05:30  2169.449951  2200.000000
# 2024-11-01 00:00:00+05:30 2024-11-01 00:00:00+05:30  2204.399902  2205.000000
#
# ...

# %%
dt=data.set_index('Date', drop=True)
dt
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30   744.956230   752.694909   744.956230   750.650757
# 2020-01-02 00:00:00+05:30   752.451561   759.606154   743.885500   754.982422
# 2020-01-03 00:00:00+05:30   755.274508   765.592707   749.531322   756.247925
# 2020-01-06 00:00:00+05:30   750.504672   753.862973   735.903414   741.889954
# 2020-01-07 00:00:00+05:30   743.690723   752.062087   732.545085   737.412170
# ...                                ...          ...          ...          ...
# 2024-10-28 00:00:00+05:30  2157.050049  2217.000000  2157.050049  2204.699951
# 2024-10-29 00:00:00+05:30  2214.649902  2214.649902  2168.399902  2206.149902
# 2024-10-30 00:00:00+05:30  2195.500000  2211.199951  2151.000000  2158.250000
# 2024-10-31 00:00:00+05:30  2169.449951  2200.000000  2148.350098  2186.949951
# 2024-11-01 00:00:00+05:30  2204.399902  2205.000000  2180.250000  2197.699951
#
# ...

# %%
dt.resample(rule='A').max()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-12-31 00:00:00+05:30  1063.874413  1099.586819  1048.737153  1063.923462
# 2021-12-31 00:00:00+05:30  1229.454226  1241.995100  1201.677999  1222.007935
# 2022-12-31 00:00:00+05:30   944.783595   957.098970   938.527402   945.276245
# 2023-12-31 00:00:00+05:30  1340.970994  1340.970994  1312.794596  1334.101074
# 2024-12-31 00:00:00+05:30  2300.000000  2312.000000  2268.000000  2290.199951
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-12-31 00:00:00+05:30  26833773        6.0           0.0
# 2021-12-31 00:00:00+05:30  26466899        6.5           0.0
# 2022-12-31 00:00:00+05:30  13258447        4.0           0.0
# 2023-12-31 00:00:00+05:30   5768804        4.0           0.0
# 2024-12-31 00:00:00+05:30   7120785        8.0           0.0

# %%
dt.resample(rule='A').min()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-12-31 00:00:00+05:30   535.379483   553.971723   491.332353   533.529968
# 2021-12-31 00:00:00+05:30   851.039233   862.960518   840.891405   845.571228
# 2022-12-31 00:00:00+05:30   582.466306   595.077201   574.387377   581.530273
# 2023-12-31 00:00:00+05:30   638.433285   645.323295   622.571660   634.467896
# 2024-12-31 00:00:00+05:30  1318.220739  1324.194549  1302.937766  1307.119385
#
#                            Volume  Dividends  Stock Splits
# Date
# 2020-12-31 00:00:00+05:30  429333        0.0           0.0
# 2021-12-31 00:00:00+05:30   63428        0.0           0.0
# 2022-12-31 00:00:00+05:30   79098        0.0           0.0
# 2023-12-31 00:00:00+05:30  223675        0.0           0.0
# 2024-12-31 00:00:00+05:30   60791        0.0           0.0

# %%
dt.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Observations:
#
# Upward Trend: The stock price displays a clear upward trend over the period shown, from 2020 to 2024. This indicates that the stock's value has been consistently increasing.
#
# Additional Notes:
#
# The chart shows a significant price increase in the final year, 2024.
# There is a dip in price in 2022, followed by a sharp recovery and continued growth.

# %%
dt.resample(rule='A').max()['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Observations:
#
# Downward Trend: The stock price displays a clear downward trend over the period shown, from 2020 to 2023, followed by a slight upward trend in 2024. This indicates that the stock's value has been decreasing overall, with a recent period of recovery.
#
# Additional Notes:
#
# The chart shows a significant price drop from 2020 to 2023.
# There is a slight recovery in the stock price in 2024, but it remains below the 2020 levels.
#
# Possible Interpretations:
#
# The downward trend could suggest that the company is facing challenges, such as declining revenue, increased competition, or operational issues.
# The recent upward trend could indicate that the company is taking steps to address its challenges and improve its performance.
#
# Further Analysis:
#
# To gain a deeper understanding of the stock's performance, it would be helpful to analyze additional factors such as:
#
# Company Fundamentals: Revenue growth, profitability, financial health, competitive position, etc.
#
# Industry Trends: Overall market trends, competitive landscape, and regulatory changes.
#
# Economic Factors: Interest rates, inflation, and overall economic growth.
#
# Investor Sentiment: News and events that could influence investor sentiment towards the stock.

# %%
dt.resample(rule='A').min()['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dt.describe().T
# Out:
#                count          mean           std           min            25%  \
# Open          1199.0  1.031041e+03  3.970399e+02    535.379483     738.920367
# High          1199.0  1.044327e+03  4.014274e+02    553.971723     749.919589
# Low           1199.0  1.016679e+03  3.925166e+02    491.332353     730.827729
# Close         1199.0  1.030050e+03  3.971071e+02    533.529968     738.750732
# Volume        1199.0  1.892182e+06  2.040361e+06  60791.000000  808067.000000
# Dividends     1199.0  2.376981e-02  3.806380e-01      0.000000       0.000000
# Stock Splits  1199.0  0.000000e+00  0.000000e+00      0.000000       0.000000
#
#                        50%           75%           max
# Open          9.240446e+02  1.140961e+03  2.300000e+03
# High          9.335027e+02  1.157052e+03  2.312000e+03
# Low           9.103499e+02  1.131870e+03  2.268000e+03
# Close         9.226160e+02  1.144482e+03  2.290200e+03
# Volume        1.280283e+06  2.218790e+06  2.683377e+07
# ...

# %%
dt['Open'].shift(1)
# Out:
# Date
# 2020-01-01 00:00:00+05:30            NaN
# 2020-01-02 00:00:00+05:30     744.956230
# 2020-01-03 00:00:00+05:30     752.451561
# 2020-01-06 00:00:00+05:30     755.274508
# 2020-01-07 00:00:00+05:30     750.504672
#                                 ...
# 2024-10-28 00:00:00+05:30    2137.800049
# 2024-10-29 00:00:00+05:30    2157.050049
# 2024-10-30 00:00:00+05:30    2214.649902
# 2024-10-31 00:00:00+05:30    2195.500000
# 2024-11-01 00:00:00+05:30    2169.449951
# Name: Open, Length: 1199, dtype: float64

# %%
dat_per_change = dt['Open']/(dt['Open'].shift(1)-1)

# %%
dat_per_change.plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Key Observations:
#
# High Volatility: The stock price exhibits significant volatility, with frequent and rapid price fluctuations both upwards and downwards. This suggests that the stock is very risky and its value can change dramatically in a short period.
#
# Lack of Clear Trend: There doesn't appear to be a consistent upward or downward trend in the stock price over the period shown. The price seems to oscillate around a certain level with no clear directional bias.
#
# Additional Notes:
#
# The high volatility makes it difficult to predict the stock's future price movements.
# Investors with a high risk tolerance might be interested in this stock, but those seeking more stable investments should likely avoid it.

# %%
dt_log_return = np.log(dt['Open']/(dt['Open'].shift(1)))

# %%
dt_log_return.plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Key Observations:
#
# High Volatility: The stock price exhibits significant volatility, with frequent and rapid price fluctuations both upwards and downwards. This suggests that the stock is very risky and its value can change dramatically in a short period.
#
# Lack of Clear Trend: There doesn't appear to be a consistent upward or downward trend in the stock price over the period shown. The price seems to oscillate around a certain level with no clear directional bias.
#
# Additional Notes:
#
# The high volatility makes it difficult to predict the stock's future price movements.
# Investors with a high risk tolerance might be interested in this stock, but those seeking more stable investments should likely avoid it.

# %%
dt.hist(bins=50,figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Dividends'}>],
#        [<Axes: title={'center': 'Stock Splits'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.histplot(data=dt['Open'], kde=True, bins=50)
# Out:
# <Axes: xlabel='Open', ylabel='Count'>

# %% [markdown]
# Observations:
#
# Multimodal Distribution: The distribution of opening prices appears to be multimodal with several peaks. This suggests that the stock's opening price may be influenced by multiple factors or events that create distinct clusters of price points.
#
# Additional Notes:
#
# The presence of multiple peaks could indicate different trading patterns or market conditions at different times.
# Further analysis would be needed to understand the factors driving these price clusters.

# %%
sns.histplot(data=dt['Close'], kde=True, bins=50)
# Out:
# <Axes: xlabel='Close', ylabel='Count'>

# %% [markdown]
# Observations:
#
# Multimodal Distribution: The distribution of closing prices appears to be multimodal with several peaks. This suggests that the stock's closing price may be influenced by multiple factors or events that create distinct clusters of price points.
#
# Additional Notes:
#
# The presence of multiple peaks could indicate different trading patterns or market conditions at different times.
# Further analysis would be needed to understand the factors driving these price clusters.

# %%
sns.histplot(dat_per_change, bins=50, kde=True, color='blue', alpha=0.6)
plt.title('Histogram with Density Line')
plt.xlabel('Percentage Change')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Key Observations:
#
# Symmetric Distribution: The distribution of percentage changes appears to be approximately symmetric, with a central peak and similar spread on both sides. This suggests that the stock's price is equally likely to move up or down by a certain percentage.
#
# Bell-shaped: The distribution roughly resembles a bell shape, which is characteristic of a normal distribution. However, there are some deviations from a perfect normal distribution, such as slight skewness or heavier tails.
#
# Volatility: The width of the distribution indicates the volatility of the stock. A wider distribution suggests higher price fluctuations, while a narrower distribution suggests lower volatility.
#
# Additional Notes:
#
# The symmetry of the distribution suggests that the stock's returns may not have a consistent directional bias.
# The presence of some deviations from a normal distribution could indicate the presence of factors that influence the stock's price in ways that are not captured by a simple normal distribution.

# %%
sns.histplot(dt_log_return, bins=50,kde=True, color='black',alpha=0.6)
plt.title('Histogram with Density line')
plt.xlabel('Log Return')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Observations:
#
# Symmetric Distribution: The distribution of log returns appears to be approximately symmetric, with a central peak and similar spread on both sides. This suggests that the stock's price is equally likely to move up or down by a certain percentage.
#
# Bell-shaped: The distribution roughly resembles a bell shape, which is characteristic of a normal distribution. However, there are some deviations from a perfect normal distribution, such as slight skewness or heavier tails.
#
# Volatility: The width of the distribution indicates the volatility of the stock. A wider distribution suggests higher price fluctuations, while a narrower distribution suggests lower volatility.
#
# Additional Notes:
#
# The symmetry of the distribution suggests that the stock's returns may not have a consistent directional bias.
# The presence of some deviations from a normal distribution could indicate the presence of factors that influence the stock's price in ways that are not captured by a simple normal distribution.

# %% [markdown]
# # **Summary of Lupin Financial Analysis**
#
# Revenue and Profitability:
#
# Revenue has shown significant growth over the reported periods, with Q2 2024 appearing to have the highest revenue.
# Net Income and Diluted EPS have also grown substantially, indicating improved profitability per share.
#
# Expenses:
#
# Operating expenses and cost of revenue have been increasing, potentially impacting profitability margins. This is a factor to monitor.
#
# Debt and Cash Flow:
#
# Total Debt has increased substantially, while Cash & Equivalents have fluctuated. This suggests a higher debt burden compared to cash reserves.
# However, Tangible Book Value has been increasing steadily, suggesting growth in the company's assets.
#
# Stock Price:
#
# The overall trend of the stock price seems to be upward over the entire period, with a significant increase in 2024.
# However, there is also significant volatility, with periods of sharp increases and decreases.
#
# Additional Observations:
#
# The number of Ordinary Shares has remained relatively stable.
# There are possible support and resistance levels visible on the stock price chart.
#
# #Conclusion:
#
# Lupin's financial performance shows signs of both growth and challenges. The company's revenue and profitability are increasing, but there are concerns about rising expenses and debt levels. The stock price is volatile but has an upward trend overall.
#
# Further Analysis:
#
# A deeper analysis of company fundamentals, industry trends, economic factors, and investor sentiment would be helpful for a more comprehensive understanding of Lupin's future prospects.
